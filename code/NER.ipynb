# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
cd drive/My\ Drive/COMP551A4
# Out:
# /content/drive/My Drive/COMP551A4

# %%
#  ! git clone https://github.com/Furiosah/glyce.git

# %%
cd glyce
# Out:
# /content/drive/My Drive/COMP551A4/glyce

# %%
#  !python3.6 setup.py develop

# %%
 pip install -r requirements.txt

# %%
# !pip install pytorch-pretrained-bert

# %%
# !pytorch_pretrained_bert convert_tf_checkpoint_to_pytorch \
# /content/drive/My\ Drive/COMP551A4/glyce/japanese/multi_cased_L-12_H-768_A-12/bert_model.ckpt \
# /content/drive/My\ Drive/COMP551A4/glyce/japanese/multi_cased_L-12_H-768_A-12/bert_config.json \
# /content/drive/My\ Drive/COMP551A4/glyce/japanese/multi_cased_L-12_H-768_A-12/pytorch_model.bin

# %%
# !bash '/content/mydrive/COMP551A4/glyce/glyce/scripts/Japanese_glyce_bert.sh'

# %%
# !bash '/content/mydrive/COMP551A4/glyce/glyce/scripts/Japanese_bert.sh'
# Out:
# /content/drive/My Drive/COMP551A4/glyce
# Traceback (most recent call last):
#   File "/content/mydrive/COMP551A4/glyce/glyce/bin/run_bert_tagger.py", line 38, in <module>
#     from glyce.utils.tokenization import BertTokenizer
#   File "/content/drive/My Drive/COMP551A4/glyce/glyce/__init__.py", line 15, in <module>
#     from .layers.char_glyph_embedding import CharGlyphEmbedding as CharGlyceEmbedding
#   File "/content/drive/My Drive/COMP551A4/glyce/glyce/layers/char_glyph_embedding.py", line 24, in <module>
#     from glyce.utils.render import multiple_glyph_embeddings, get_font_names
#   File "/content/drive/My Drive/COMP551A4/glyce/glyce/utils/render.py", line 26, in <module>
#     default_font = ImageFont.truetype(os.path.join(default_font_path, default_font_name), default_font_size)
#   File "/usr/local/lib/python3.6/dist-packages/PIL/ImageFont.py", line 259, in truetype
#     return FreeTypeFont(font, size, index, encoding, layout_engine)
# ...

# %%
# !bash '/content/drive/My Drive/COMP551A4/glyce/glyce/scripts/fudan_glyce_bert.sh'

# %%
# !bash '/content/mydrive/COMP551A4/glyce/glyce/cws/cityu_glyce_bert.sh'

# %%
# !bash '/content/mydrive/COMP551A4/glyce/glyce/scripts/cityu_bert.sh'

# %%
# !ln -s "/content/drive/My Drive" "/content/mydrive"

# %%
pip install comet_ml
